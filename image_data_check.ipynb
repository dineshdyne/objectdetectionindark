# %%
import cv2
from PIL import Image
import tensorflow as tf
import matplotlib.pyplot as plt
import keras
from itertools import *
# Out:
# Note: NumExpr detected 16 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# NumExpr defaulting to 8 threads.

# %%
import hub

# %%
import hub
ds = hub.load('hub://activeloop/lowlight-val')
# Out:
# Opening dataset in read-only mode as you don't have write permissions.
# hub://activeloop/lowlight-val loaded successfully.
# This dataset can be visualized at https://app.activeloop.ai/activeloop/lowlight-val.

# %%
dataloader = ds.tensorflow()
# Out:
# 2022-04-11 20:12:19.186509: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Out:
# 14

# %% [markdown]
# ## PIL

# %%
low_light_img = Image.open(
    'sample_test_cases/img1.jpg').convert('RGB')
low_light_img
# Out:
# <PIL.Image.Image image mode=RGB size=282x179>

# %%
type(low_light_img)
# Out:
# PIL.Image.Image

# %%
plt.imshow(low_light_img)

# %%
import numpy as np
plt.imshow(cv2.resize(keras.preprocessing.image.img_to_array(low_light_img).astype(int),(256,256),interpolation=cv2.INTER_NEAREST).astype(int))

# %%
im1=keras.preprocessing.image.img_to_array(low_light_img)

# %%
all(list(chain.from_iterable(chain.from_iterable((im1.astype(int)==im)))))
# Out:
# True

# %%
np.min(im1)
# Out:
# 0.0

# %%
im
# Out:
# array([[[101,  71,  73],
#         [107,  76,  71],
#         [123,  86,  67],
#         ...,
#         [ 36,  56,  67],
#         [ 20,  42,  55],
#         [ 20,  42,  55]],
#
#        [[ 92,  66,  65],
#         [ 99,  72,  65],
#         [113,  80,  61],
#         ...,
#         [ 39,  57,  71],
#         [ 23,  42,  56],
#         [ 23,  42,  56]],
#
#        [[ 78,  64,  55],
#         [ 85,  67,  55],
#         [ 98,  72,  57],
#         ...,
#         [ 42,  58,  74],
#         [ 32,  48,  64],
#         [ 32,  48,  64]],
#
#        ...,
#
#        [[ 15,  42,  63],
#         [ 15,  42,  63],
#         [ 15,  42,  63],
#         ...,
#         [ 15,  41,  64],
#         [ 14,  40,  63],
#         [ 14,  40,  63]],
#
#        [[ 15,  42,  63],
#         [ 15,  42,  63],
#         [ 15,  42,  63],
#         ...,
#         [ 15,  41,  64],
#         [ 14,  40,  63],
#         [ 14,  40,  63]],
#
#        [[ 15,  42,  63],
#         [ 15,  42,  63],
#         [ 15,  42,  63],
# ...

# %%
keras.preprocessing.image.img_to_array(low_light_img.resize((256,256),Image.NEAREST))
# Out:
# /var/folders/kn/v4t8jjps02sd9mchfjfy9trm0000gn/T/ipykernel_9067/2327101725.py:2: DeprecationWarning: NEAREST is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.NEAREST or Dither.NONE instead.
#   keras.preprocessing.image.img_to_array(low_light_img.resize((256,256),Image.NEAREST))
# array([[[101.,  71.,  73.],
#         [107.,  76.,  71.],
#         [123.,  86.,  67.],
#         ...,
#         [ 36.,  56.,  67.],
#         [ 20.,  42.,  55.],
#         [ 20.,  42.,  55.]],
#
#        [[ 92.,  66.,  65.],
#         [ 99.,  72.,  65.],
#         [113.,  80.,  61.],
#         ...,
#         [ 39.,  57.,  71.],
#         [ 23.,  42.,  56.],
#         [ 23.,  42.,  56.]],
#
#        [[ 92.,  66.,  65.],
#         [ 99.,  72.,  65.],
#         [113.,  80.,  61.],
#         ...,
#         [ 39.,  57.,  71.],
#         [ 23.,  42.,  56.],
#         [ 23.,  42.,  56.]],
#
#        ...,
#
#        [[ 15.,  42.,  63.],
#         [ 15.,  42.,  63.],
# ...

# %% [markdown]
# ## CV2

# %%
import cv2

im = cv2.imread('sample_test_cases/img1.jpg', cv2.COLOR_BGR2RGB)#[:, :, ::-1]
im=cv2.cvtColor(im,cv2.COLOR_BGR2RGB)

plt.imshow(im)

# %%
im.shape, type(im)
# Out:
# ((179, 282, 3), numpy.ndarray)

# %%
low_light_img

# %%
cv2.INTER

# %%
im2=cv2.resize(im, (256, 256),
           interpolation=cv2.INTER_NEAREST)
plt.imshow(im2)

# %%
Image.fromarray(im2)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>
